# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing the dataset**

# %%
import pandas as pd
columns = ['sentiment_rating','id','date','query','user','text']
df = pd.read_csv("/content/drive/MyDrive/Datasets/data.csv",encoding='latin-1',names = columns)
df.head(5)
# Out:
#    sentiment_rating          id                          date     query  \
# 0                 0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                 0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                 0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                 0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                 0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# ## **Analysis & Preprocessing of the dataset**

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df['query'].value_counts()
# Out:
# NO_QUERY    1600000
# Name: query, dtype: int64

# %%
df.drop(labels = ['query','date','id'],axis = 1,inplace = True)
df.head(5)
# Out:
#    sentiment_rating             user  \
# 0                 0  _TheSpecialOne_
# 1                 0    scotthamilton
# 2                 0         mattycus
# 3                 0          ElleCTF
# 4                 0           Karoli
#
#                                                 text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
#For Links
df['text'] = df['text'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)

#For Symbols
pattern = r'[^\w\s]'
df['text'] = df['text'].replace(pattern, '',regex = True)
df['text'] = df['text'].replace('_', '', regex = True)
df['user'] = df['user'].replace('_', '', regex = True)
df.head(50)
# Out:
#     sentiment_rating             user  \
# 0                  0    TheSpecialOne
# 1                  0    scotthamilton
# 2                  0         mattycus
# 3                  0          ElleCTF
# 4                  0           Karoli
# 5                  0          joywolf
# 6                  0          mybirch
# 7                  0             coZZ
# 8                  0  2Hood4Hollywood
# 9                  0          mimismo
# 10                 0   erinx3leannexo
# 11                 0     pardonlauren
# 12                 0             TLeC
# 13                 0  robrobbierobert
# 14                 0      bayofwolves
# 15                 0       HairByJess
# 16                 0   lovesongwriter
# 17                 0         armotley
# 18                 0       starkissed
# 19                 0          gigibee
# 20                 0           quanvu
# 21                 0       swinspeedx
# 22                 0        cooliodoc
# 23                 0       viJILLante
# 24                 0       Ljelli3166
# 25                 0    ChicagoCubbie
# 26                 0      KatieAngell
# 27                 0            gagoo
# 28                 0          abel209
# 29                 0  BaptisteTheFool
# 30                 0        fatkat309
# 31                 0            EmCDL
# 32                 0         merisssa
# 33                 0         Pbearfox
# 34                 0             jsoo
# 35                 0   scarletletterm
# 36                 0       crosland12
# 37                 0          ajaxpro
# 38                 0          Tmttq86
# 39                 0    AnthonyNguyen
# 40                 0       itsanimesh
# 41                 0        lionslamb
# 42                 0        kennypham
# 43                 0   DdubsShellBell
# 44                 0      hpfangirl94
# 45                 0        antzpantz
# 46                 0        labrt2004
# 47                 0        IrisJumbe
# 48                 0         peacoats
# 49                 0         cyantist
#
#                                                  text
# 0   switchfoot   A thats a bummer  You shoulda got...
# 1   is upset that he cant update his Facebook by t...
# 2   Kenichan I dived many times for the ball Manag...
# 3     my whole body feels itchy and like its on fire
# 4   nationwideclass no its not behaving at all im ...
# 5                        Kwesidei not the whole crew
# 6                                         Need a hug
# 7   LOLTrish hey  long time no see Yes Rains a bit...
# 8                   TatianaK nope they didnt have it
# 9                             twittera que me muera
# 10            spring break in plain city its snowing
# 11                          I just repierced my ears
# 12  caregiving I couldnt bear to watch it  And I t...
# 13  octolinz16 It it counts idk why I did either y...
# 14  smarrison i wouldve been the first but i didnt...
# 15  iamjazzyfizzle I wish I got to watch it with y...
# 16  Hollis death scene will hurt me severely to wa...
# 17                               about to file taxes
# 18  LettyA ahh ive always wanted to see rent  love...
# 19  FakerPattyPattz Oh dear Were you drinking out ...
# 20  alydesigns i was out most of the day so didnt ...
# 21  one of my friend called me and asked to meet w...
# 22     angrybarista I baked you a cake but I ated it
# 23             this week is not going as i had hoped
# 24                         blagh class at 8 tomorrow
# 25     I hate when I have to call and wake people up
# 26  Just going to cry myself to sleep after watchi...
# 27                              im sad now  MissLilly
# 28  ooooh LOL  that leslie and ok I wont do it aga...
# 29  Meh Almost Lover is the exception this track g...
# 30  some1 hacked my account on aim  now i have to ...
# 31  alielayus I want to go to promote GEAR AND GRO...
# 32  thought sleeping in was an option tomorrow but...
# 33  julieebaby awe i love you too 1 am here  i mis...
# 34   HumpNinja I cry my asian eyes to sleep at night
# 35  ok Im sick and spent an hour sitting in the sh...
# 36  cocomix04 ill tell ya the story later  not a g...
# 37            MissXu sorry bed time came here GMT1
# 38  fleurylis I dont either Its depressing I dont ...
# 39  Bed Class 812 Work 123 Gym 35 or 6 Then class ...
# 40  really dont feel like getting up today but got...
# 41  Hes the reason for the teardrops on my guitar ...
# 42  Sad sad sad I dont know why but I hate this fe...
# 43  JonathanRKnight Awww I soo wish I was there to...
# 44  Falling asleep Just heard about that Tracy gir...
# 45  Viennah Yay Im happy for you with your job But...
# 46  Just checked my user timeline on my blackberry...
# 47  Oh manwas ironing jeancjumbes fave top to wear...
# 48  is strangely sad about LiLo and SamRo breaking...
# 49  tea oh im so sorry  i didnt think about that b...

# %% [markdown]
# ## **Stemming**

# %%
from nltk.stem import PorterStemmer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
  stemmed_content = content.lower()
  stemmed_content = stemmed_content.split()
  stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
  stemmed_content = ' '.join(stemmed_content)

  return stemmed_content

# %%
#df['stemmed_content'] = df['text'].apply(stemming)

# %% [markdown]
# ## **Classifying labels**

# %%
df['sentiment_rating'].value_counts()
# Out:
# 0    800000
# 4    800000
# Name: sentiment_rating, dtype: int64

# %%
#On the basis of this, two classifications are possible, one negative and one positive
df['sentiment_rating'] = df['sentiment_rating'].replace(4,1,regex = True)
df.head(5)
# Out:
#    sentiment_rating           user  \
# 0                 0  TheSpecialOne
# 1                 0  scotthamilton
# 2                 0       mattycus
# 3                 0        ElleCTF
# 4                 0         Karoli
#
#                                                 text
# 0  switchfoot   A thats a bummer  You shoulda got...
# 1  is upset that he cant update his Facebook by t...
# 2  Kenichan I dived many times for the ball Manag...
# 3    my whole body feels itchy and like its on fire
# 4  nationwideclass no its not behaving at all im ...

# %% [markdown]
# ## **Splitting the dataset**

# %%
X = df['text'].values
y = df['sentiment_rating'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
import warnings
warnings.filterwarnings("ignore")

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1600000,) (1280000,) (320000,)

# %% [markdown]
# ## **Feature Extraction(Converting to Numerical Values)**

# %%
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %% [markdown]
# ## **Logistic Regression Model**

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(y_train, X_train_prediction)
training_data_precision = precision_score(y_train,X_train_prediction)
training_data_recall = recall_score(y_train,X_train_prediction)
training_data_f1 = f1_score(y_train,X_train_prediction)

X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(y_test, X_test_prediction)
testing_data_precision = precision_score(y_test,X_test_prediction)
testing_data_recall = recall_score(y_test,X_test_prediction)
testing_data_f1 = f1_score(y_test,X_test_prediction)

# %%
print(f"Testing Data Accuracy: {testing_data_accuracy} \nTraining Data Accuracy: {training_data_accuracy}")
print(f"\nTesting Data Precision: {testing_data_precision} \nTraining Data Precision: {training_data_precision}")
print(f"\nTesting Data Recall: {testing_data_recall} \nTraining Data Recall: {training_data_recall}")
print(f"\nTesting Data f1: {testing_data_f1} \nTraining Data f1: {training_data_f1}")
# Out:
# Testing Data Accuracy: 0.7986875
# Training Data Accuracy: 0.81021953125
#
# Testing Data Precision: 0.7931319894055326
# Training Data Precision: 0.7991702420403667
#
# Testing Data Recall: 0.8083065695254995
# Training Data Recall: 0.8286528178411708
#
# Testing Data f1: 0.8006473853923614
# Training Data f1: 0.8136445407644656

# %%
X_data = X_test[150]
print(y_test[150])
prediction = model.predict(X_data)
print(prediction)
# Out:
# 1
# [1]

# %% [markdown]
# ## **Testing the model on custom data**

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    text = text.lower()
    text = text.split()
    text = [word for word in text if not word in set(stopwords.words('english'))]
    text = ' '.join(text)
    return text

def predict_sentiment(input_text):
    input_text = preprocess_text(input_text)
    input_vectorized = vectorizer.transform([input_text])
    prediction = model.predict(input_vectorized)

    if prediction[0] == 0:
        return 'Negative Tweet'
    else:
        return 'Positive Tweet'

# %%
user_input = input("Enter a tweet: ")
result = predict_sentiment(user_input)
print("Prediction:", result)
# Out:
# Enter a tweet: you are a black piece of shit
# Prediction: Negative Tweet
