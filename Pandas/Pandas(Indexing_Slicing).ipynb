# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Working with pandas

# %%
import pandas as pd

# %% [markdown]
# Creating a custom dataframe

# %%
data = {
    'Name':['John','Lisa','Mary','Jonathan','Gary'],
    'Age':[15,20,30,50,70],
    'Salary':[10000,40000,50000,60000,70000]
}

df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Salary
# 0      John   15   10000
# 1      Lisa   20   40000
# 2      Mary   30   50000
# 3  Jonathan   50   60000
# 4      Gary   70   70000

# %% [markdown]
# import a csv

# %%
df_stk = pd.read_csv("/content/drive/MyDrive/Datasets/tesla-stock-price.csv")
df_stk.head(5)
# Out:
#          date   close    volume    open    high       low
# 0  15-10-2018  259.59   6189026  259.06  263.28  254.5367
# 1  12-10-2018  258.78   7189257  261.00  261.99  252.0100
# 2  11-10-2018  252.23   8128184  257.53  262.25  249.0300
# 3  10-10-2018  256.88  12781560  264.61  265.51  247.7700
# 4  09-10-2018  262.80  12037780  255.25  266.77  253.3000

# %% [markdown]
# Indexing and Slicing

# %%
df['Age']
# Out:
# 0    15
# 1    20
# 2    30
# 3    50
# 4    70
# Name: Age, dtype: int64

# %%
# using loc
df.loc[1:2,['Name','Salary']]
# Out:
#    Name  Salary
# 1  Lisa   40000
# 2  Mary   50000

# %%
# using iloc
# one for row and col
df.iloc[:2,:2]
# Out:
#    Name  Age
# 0  John   15
# 1  Lisa   20

# %% [markdown]
# Sorting and Filtering

# %%
df.sort_values(by=['Name','Salary'],ascending = [True,False])
# Out:
#        Name  Age  Salary
# 4      Gary   70   70000
# 0      John   15   10000
# 3  Jonathan   50   60000
# 1      Lisa   20   40000
# 2      Mary   30   50000

# %%
filteredata = df[(df['Age'] > 20) & (df['Salary'] < 60000)]
print(filteredata)
# Out:
#    Name  Age  Salary
# 2  Mary   30   50000

# %% [markdown]
# Mapping data

# %%
mapped = {'Lisa':2,'Jonathan':1,'Lisa':5,'Mary':3,'Gary':3}
df['Proficiency'] = df['Name'].map(mapped)
df
# Out:
#        Name  Age  Salary  Proficiency
# 0      John   15   10000          NaN
# 1      Lisa   20   40000          5.0
# 2      Mary   30   50000          3.0
# 3  Jonathan   50   60000          1.0
# 4      Gary   70   70000          3.0
